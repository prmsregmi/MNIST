# %%
from src.activation import ReLU
from src.nn import LinearLayer, SGDWithMomentum
from src.loss import CrossEntropyLoss
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import numpy as np

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
])

# Load the training and test datasets
train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
test_dataset  = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

# Define data loaders
batch_size = 32
train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
test_loader  = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

# %%
input_layer = LinearLayer(784, 256)
relu1 = ReLU()
hidden_layer = LinearLayer(256, 128)
relu2 = ReLU()
output_layer = LinearLayer(128, 10)
criterion = CrossEntropyLoss()

# Collect parameters and gradients for the optimizer
parameters = [input_layer.weights, input_layer.bias,
            hidden_layer.weights, hidden_layer.bias,
            output_layer.weights, output_layer.bias]

gradients = [input_layer.weights_grad, input_layer.bias_grad,
            hidden_layer.weights_grad, hidden_layer.bias_grad,
            output_layer.weights_grad, output_layer.bias_grad]

# Initialize optimizer
optimizer = SGDWithMomentum(parameters, learning_rate=0.1, momentum=0.9)

# Training loop
num_epochs = 60
patience = 5
trigger_times = 0
best_loss = float('inf')

for epoch in range(num_epochs):
    epoch_loss = 0
    for batch_idx, (data, target) in enumerate(train_loader):
        # Prepare input and labels
        data = data.view(-1, 28*28).numpy()
        data = (data - data.mean()) / (data.std() + 1e-8)
        target = target.numpy()
        
        # Forward pass
        out = input_layer.forward(data)
        out = relu1.forward(out)
        out = hidden_layer.forward(out)
        out = relu2.forward(out)
        out = output_layer.forward(out)
        loss = criterion.forward(out, target)
        
        # Backward pass
        grad_loss = criterion.backward()
        grad_output = output_layer.backward(grad_loss)
        grad_relu2 = relu2.backward(grad_output)
        grad_hidden = hidden_layer.backward(grad_relu2)
        grad_relu1 = relu1.backward(grad_hidden)
        grad_input = input_layer.backward(grad_relu1)
        
        # Print gradients to check if they are non-zero and sensible
        print("Gradients for input layer weights:", np.mean(input_layer.weights_grad))
        print("Gradients for hidden layer weights:", np.mean(hidden_layer.weights_grad))
        print("Gradients for output layer weights:", np.mean(output_layer.weights_grad))

        optimizer.step(parameters, gradients)
        
        input_layer.zero_grad()
        hidden_layer.zero_grad()
        output_layer.zero_grad()
        
        epoch_loss += loss

    # Print average loss for the epoch
    avg_loss = epoch_loss / len(train_loader)
    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {avg_loss:.4f}')
    
    # Early stopping
    if avg_loss < best_loss:
        best_loss = avg_loss
        trigger_times = 0
    else:
        trigger_times += 1
        if trigger_times >= patience:
            print('Early stopping on epoch:', epoch)
            break
# Out:
# Gradients for input layer weights: -9.225513329476314e-05
# Gradients for hidden layer weights: 0.00023099092524554314
# Gradients for output layer weights: -4.98732999343332e-19
# Gradients for input layer weights: -2.839363233550367e-06
# Gradients for hidden layer weights: 0.0012072990994847041
# Gradients for output layer weights: -3.2526065174565133e-19
# Gradients for input layer weights: -1.1658616210003862e-07
# Gradients for hidden layer weights: 0.0019772256096315757
# Gradients for output layer weights: -1.0842021724855044e-19
# Gradients for input layer weights: -7.811919267120919e-05
# Gradients for hidden layer weights: -0.0003006361539481362
# Gradients for output layer weights: -1.3444106938820255e-18
# Gradients for input layer weights: -1.0939919490216022e-05
# Gradients for hidden layer weights: 0.0028755555200341695
# Gradients for output layer weights: 2.168404344971009e-19
# Gradients for input layer weights: 7.27603152734289e-05
# Gradients for hidden layer weights: -3.5801303264304976e-05
# Gradients for output layer weights: 6.071532165918824e-19
# Gradients for input layer weights: 8.303942323101523e-06
# Gradients for hidden layer weights: 0.001837900058330959
# Gradients for output layer weights: -2.5587171270657906e-18
# Gradients for input layer weights: 7.376842857850559e-05
# Gradients for hidden layer weights: 0.0011383023350047107
# Gradients for output layer weights: -2.3310346708438344e-19
# Gradients for input layer weights: -2.331843252301504e-05
# Gradients for hidden layer weights: 0.0013495907059642835
# Gradients for output layer weights: -1.6588293239028219e-18
# Gradients for input layer weights: 5.2269748872241695e-05
# Gradients for hidden layer weights: 0.00013310110846159333
# Gradients for output layer weights: -3.279711571768651e-19
# Gradients for input layer weights: 1.6383347622503776e-05
# Gradients for hidden layer weights: 0.0004523231706347784
# Gradients for output layer weights: -2.439454888092385e-18
# Gradients for input layer weights: -0.00011989927558871442
# Gradients for hidden layer weights: 0.0014662961304835556
# Gradients for output layer weights: 1.3227266504323153e-18
# Gradients for input layer weights: 1.7873112532350815e-05
# Gradients for hidden layer weights: 0.0019603096209769477
# Gradients for output layer weights: 7.752045533271357e-19
# Gradients for input layer weights: -7.391922008192605e-05
# Gradients for hidden layer weights: 0.0006786944935914144
# Gradients for output layer weights: -9.64939933512099e-19
# Gradients for input layer weights: 1.7251491645184064e-06
# Gradients for hidden layer weights: 0.0004182241000375925
# Gradients for output layer weights: -8.782037597132586e-19
# Gradients for input layer weights: -1.6268582316020172e-05
# Gradients for hidden layer weights: 0.00042397165596490494
# Gradients for output layer weights: 7.995991022080595e-19
# Gradients for input layer weights: 1.736527773118069e-05
# Gradients for hidden layer weights: 0.000543284866103871
# Gradients for output layer weights: -6.993104012531504e-19
# Gradients for input layer weights: -6.333255082861876e-05
# Gradients for hidden layer weights: 0.002142777154467253
# Gradients for output layer weights: -7.26415455565288e-19
# Gradients for input layer weights: -1.8220869119184944e-05
# Gradients for hidden layer weights: 0.00026268677413306346
# Gradients for output layer weights: 2.49366499671666e-19
# Gradients for input layer weights: -3.65176358862205e-06
# Gradients for hidden layer weights: 0.001340295478319632
# Gradients for output layer weights: 6.423897871976614e-19
# Gradients for input layer weights: 0.00011073276225516738
# Gradients for hidden layer weights: 0.0013827892376024214
# Gradients for output layer weights: 4.553649124439119e-19
# Gradients for input layer weights: 2.1535367525812253e-05
# Gradients for hidden layer weights: 0.0005630943197233396
# Gradients for output layer weights: -3.035766082959412e-19
# Gradients for input layer weights: -4.5992329768334556e-05
# Gradients for hidden layer weights: 0.0020288863801147436
# Gradients for output layer weights: -1.0191500421363742e-18
# Gradients for input layer weights: 2.7844044181254825e-05
# Gradients for hidden layer weights: 0.0010848819334232833
# Gradients for output layer weights: 1.517883041479706e-19
# Gradients for input layer weights: 3.245613051417869e-05
# Gradients for hidden layer weights: 0.0013671250090035877
# Gradients for output layer weights: 6.505213034913026e-20
# Gradients for input layer weights: 1.8051369492350836e-05
# Gradients for hidden layer weights: 0.0011117878989465404
# Gradients for output layer weights: -4.553649124439119e-19
# Gradients for input layer weights: 0.00017588080088427012
# Gradients for hidden layer weights: 0.0011390198221818701
# Gradients for output layer weights: 4.824699667560495e-19
# Gradients for input layer weights: 3.914283515177874e-05
# Gradients for hidden layer weights: 0.0026561476779772804
# Gradients for output layer weights: 4.336808689942018e-19
# Gradients for input layer weights: 0.00010274824922467296
# Gradients for hidden layer weights: 0.0024050020910555197
# Gradients for output layer weights: -1.3552527156068805e-18
# Gradients for input layer weights: 1.0130819038834699e-05
# Gradients for hidden layer weights: 0.0010794006204313338
# Gradients for output layer weights: -4.553649124439119e-19
# Gradients for input layer weights: -6.249059114726212e-05
# Gradients for hidden layer weights: 0.0009403616443264772
# Gradients for output layer weights: -1.1058862159352144e-18
# Gradients for input layer weights: -3.206847504722245e-05
# Gradients for hidden layer weights: 0.0015495780144866153
# Gradients for output layer weights: 4.77048955893622e-19
# Gradients for input layer weights: -9.609695474041506e-06
# Gradients for hidden layer weights: 0.0015538392054469682
# Gradients for output layer weights: 2.6020852139652105e-19
# Gradients for input layer weights: -2.4963070145352124e-05
# Gradients for hidden layer weights: 0.0003434517387081551
# Gradients for output layer weights: -1.0842021724855044e-19
# Gradients for input layer weights: 5.358279463827506e-05
# Gradients for hidden layer weights: 0.001028886242326243
# Gradients for output layer weights: -3.035766082959412e-19
# Gradients for input layer weights: -0.00010226754413425233
# Gradients for hidden layer weights: 0.0009006969289203508
# Gradients for output layer weights: 2.168404344971009e-20
# Gradients for input layer weights: -2.7995341263731536e-05
# Gradients for hidden layer weights: 0.0012651719792730314
# Gradients for output layer weights: 2.1141942363467336e-19
# Gradients for input layer weights: 6.146096300796893e-05
# Gradients for hidden layer weights: 0.0010130539222740261
# Gradients for output layer weights: 3.7947076036992655e-19
# Gradients for input layer weights: -3.7373640536162986e-05
# Gradients for hidden layer weights: 0.0009733343812941386
# Gradients for output layer weights: -1.6263032587282566e-20
# Gradients for input layer weights: 8.607122277226035e-05
# Gradients for hidden layer weights: 0.0011865502773741041
# Gradients for output layer weights: -7.697835424647081e-19
# Gradients for input layer weights: -0.0001568853008563941
# Gradients for hidden layer weights: 0.001380346917044865
# Gradients for output layer weights: 3.4694469519536144e-19
# Gradients for input layer weights: 0.00014446002435508344
# Gradients for hidden layer weights: 0.002759677191773004
# Gradients for output layer weights: 1.0842021724855044e-19
# Gradients for input layer weights: 5.387417939224411e-05
# Gradients for hidden layer weights: 0.0018167680895855415
# Gradients for output layer weights: -2.8433201973432355e-18
# Gradients for input layer weights: -1.0426672915017038e-05
# Gradients for hidden layer weights: 0.0008619765587607471
# Gradients for output layer weights: 1.3227266504323153e-18
# Gradients for input layer weights: 0.00010911912838599655
# Gradients for hidden layer weights: 0.0019432891531703247
# Gradients for output layer weights: -2.168404344971009e-19
# Gradients for input layer weights: -2.2120930895871002e-05
# Gradients for hidden layer weights: 0.0006658380227112753
# Gradients for output layer weights: -3.4694469519536144e-19
# Gradients for input layer weights: 4.3535597740922564e-05
# Gradients for hidden layer weights: 0.0009148385973435866
# Gradients for output layer weights: 3.686287386450715e-19
# Gradients for input layer weights: 0.00017533350772102523
# Gradients for hidden layer weights: 0.0019479784091040522
# Gradients for output layer weights: -7.26415455565288e-19
# Gradients for input layer weights: -4.7359498350012995e-05
# Gradients for hidden layer weights: 0.001757320567163438
# Gradients for output layer weights: -9.107298248878238e-19
# Gradients for input layer weights: -7.160832202857185e-05
# Gradients for hidden layer weights: 0.000875015283192965
# Gradients for output layer weights: -1.7889335846010822e-19
# Gradients for input layer weights: 8.276329000864858e-06
# Gradients for hidden layer weights: 0.0016774913546652556
# Gradients for output layer weights: 1.1167282376600696e-18
# Gradients for input layer weights: -8.614047251157437e-06
# Gradients for hidden layer weights: 0.000683987761638413
# Gradients for output layer weights: 3.0899761915836877e-19
# Gradients for input layer weights: 9.216075328283238e-06
# Gradients for hidden layer weights: 0.0019509036061204203
# Gradients for output layer weights: -5.637851296924623e-19
# Gradients for input layer weights: 3.114607998866531e-05
# Gradients for hidden layer weights: 0.0013985660353742308
# Gradients for output layer weights: -3.144186300207963e-19
# Gradients for input layer weights: -5.7028909868309456e-05
# Gradients for hidden layer weights: 0.0016943988734318453
# Gradients for output layer weights: -2.927345865710862e-19
# Gradients for input layer weights: 0.0001244444751433383
# Gradients for hidden layer weights: 0.0016686409789027435
# Gradients for output layer weights: 5.963111948670274e-19
# Gradients for input layer weights: -4.907588907649948e-05
# Gradients for hidden layer weights: 0.0008953592483353736
# Gradients for output layer weights: 2.0166160408230384e-18
# Gradients for input layer weights: 9.445135547472162e-05
# Gradients for hidden layer weights: 0.001680184000890708
# Gradients for output layer weights: 7.806255641895632e-19
# Gradients for input layer weights: 8.414373721232584e-06
# Gradients for hidden layer weights: 0.0010385186654138445
# Gradients for output layer weights: -1.7889335846010822e-19
# Gradients for input layer weights: 2.374066373707464e-05
# Gradients for hidden layer weights: 0.0009580883051821751
# Gradients for output layer weights: 9.703609443745264e-19
# Gradients for input layer weights: 9.817006736689837e-05
# Gradients for hidden layer weights: 0.002193379279873029
# Gradients for output layer weights: -2.8297676701871667e-18
# Gradients for input layer weights: -7.364077250925682e-07
# Gradients for hidden layer weights: 0.0010908104560909083
# Gradients for output layer weights: 1.1275702593849246e-18
# Gradients for input layer weights: -0.00013963378683484983
# Gradients for hidden layer weights: 0.002120906449110003
# Gradients for output layer weights: -1.1384122811097797e-18
# Gradients for input layer weights: -3.086677590804283e-05
# Gradients for hidden layer weights: 0.0005857682826961556
# Gradients for output layer weights: -6.667843360785853e-19
# Gradients for input layer weights: -1.0837360350961135e-05
# Gradients for hidden layer weights: 0.0021925352975519933
# Gradients for output layer weights: 1.5016200088924236e-18
# Gradients for input layer weights: -3.708144870239995e-05
# Gradients for hidden layer weights: 0.0017445629506357568
# Gradients for output layer weights: -1.463672932855431e-19
# Gradients for input layer weights: -2.5944719136060333e-05
# Gradients for hidden layer weights: 0.001467968699627238
# Gradients for output layer weights: 9.324138683375338e-19
# Gradients for input layer weights: 0.0001219371359246885
# Gradients for hidden layer weights: 0.00022455822250013136
# Gradients for output layer weights: 5.204170427930421e-19
# Gradients for input layer weights: -9.590702685798405e-05
# Gradients for hidden layer weights: 0.0004884999950667438
# Gradients for output layer weights: 7.914675859144182e-19
# Gradients for input layer weights: 1.0453280795606462e-05
# Gradients for hidden layer weights: 0.00028799115695827984
# Gradients for output layer weights: -3.686287386450715e-19
# Gradients for input layer weights: 7.349395814129942e-05
# Gradients for hidden layer weights: 0.0028978557439655337
# Gradients for output layer weights: 7.047314121155779e-19
# Gradients for input layer weights: -1.5233196902886402e-05
# Gradients for hidden layer weights: 0.0017356436028617968
# Gradients for output layer weights: -2.38524477946811e-19
# Gradients for input layer weights: -0.00012259405553456735
# Gradients for hidden layer weights: 0.0020074272738613555
# Gradients for output layer weights: -8.239936510889833e-19
# Gradients for input layer weights: -3.4336495221372906e-05
# Gradients for hidden layer weights: 0.0005791706038273736
# Gradients for output layer weights: 2.358139725155972e-19
# Gradients for input layer weights: -2.537692207429006e-05
# Gradients for hidden layer weights: 0.00144972320881689
# Gradients for output layer weights: 7.426784881525705e-19
# Gradients for input layer weights: 0.00013210128508083844
# Gradients for hidden layer weights: 0.001332702978496986
# Gradients for output layer weights: -3.3068166260807883e-19
# Gradients for input layer weights: -9.874991150757561e-05
# Gradients for hidden layer weights: 0.0013744517488386938
# Gradients for output layer weights: 9.54097911787244e-19
# Gradients for input layer weights: -9.088192726724274e-06
# Gradients for hidden layer weights: 0.0014548603607324132
# Gradients for output layer weights: 2.656295322589486e-19
# Gradients for input layer weights: -7.462285459766853e-05
# Gradients for hidden layer weights: 0.0019863825821379633
# Gradients for output layer weights: -4.174178364069192e-19
# Gradients for input layer weights: -2.2033293980809335e-05
# Gradients for hidden layer weights: 0.002972936273430699
# Gradients for output layer weights: -9.2970336290632e-19
# Gradients for input layer weights: -0.00010678712120276829
# Gradients for hidden layer weights: 0.0014160674252561786
# Gradients for output layer weights: 1.4961989980299962e-18
# Gradients for input layer weights: -0.00018483230753437533
# Gradients for hidden layer weights: 0.00031416794828634047
# Gradients for output layer weights: 1.3660947373317355e-18
# Gradients for input layer weights: 4.593051747151912e-05
# Gradients for hidden layer weights: 0.001329860783438289
# Gradients for output layer weights: 1.8973538018496328e-18
# Gradients for input layer weights: -5.447321353878757e-05
# Gradients for hidden layer weights: 0.001569394596776494
# Gradients for output layer weights: 8.239936510889833e-19
# Gradients for input layer weights: -2.454313290458398e-06
# Gradients for hidden layer weights: 0.000934728234310273
# Gradients for output layer weights: 1.0570971181733668e-18
# Gradients for input layer weights: 0.00013447710353235774
# Gradients for hidden layer weights: 0.00215151833425459
# Gradients for output layer weights: 6.505213034913027e-19
# Gradients for input layer weights: -8.926545831806676e-05
# Gradients for hidden layer weights: 0.001143089921650635
# Gradients for output layer weights: 1.680513367352532e-19
# Gradients for input layer weights: -4.6178235683130114e-05
# Gradients for hidden layer weights: 0.0019388294664140725
# Gradients for output layer weights: 1.2143064331837649e-18
# Gradients for input layer weights: -2.379489196858924e-05
# Gradients for hidden layer weights: 0.001818070505463194
# Gradients for output layer weights: -1.6805133673525319e-18
# Gradients for input layer weights: -2.0046461851542573e-05
# Gradients for hidden layer weights: 0.0011874748248264845
# Gradients for output layer weights: -5.204170427930421e-19
# Gradients for input layer weights: 3.613645493888942e-05
# Gradients for hidden layer weights: 0.00217645931311217
# Gradients for output layer weights: 8.510987054011209e-19
# Gradients for input layer weights: 4.359129200551146e-05
# Gradients for hidden layer weights: 0.000871179617566067
# Gradients for output layer weights: -9.64939933512099e-19
# Gradients for input layer weights: -2.105687192787155e-05
# Gradients for hidden layer weights: 0.0015837758203310014
# Gradients for output layer weights: -5.204170427930421e-19
# Gradients for input layer weights: -0.00011814709590861337
# Gradients for hidden layer weights: 0.0013425843361146057
# Gradients for output layer weights: -2.710505431213761e-19
# Gradients for input layer weights: -2.9674231585011924e-05
# Gradients for hidden layer weights: 0.0016819570785002148
# Gradients for output layer weights: 3.1983964088322383e-19
# Gradients for input layer weights: 1.2713819175936402e-05
# Gradients for hidden layer weights: 0.002267286008994978
# Gradients for output layer weights: 6.830473686658678e-19
# Gradients for input layer weights: -2.5851414537229518e-05
# Gradients for hidden layer weights: 0.0012597574213840726
# Gradients for output layer weights: 1.474514954580286e-18
# Gradients for input layer weights: -2.6071318590960235e-06
# Gradients for hidden layer weights: 0.001023531272476738
# Gradients for output layer weights: -5.095750210681871e-19
# Gradients for input layer weights: 9.52837088858306e-05
# Gradients for hidden layer weights: 0.000955969647353907
# Gradients for output layer weights: 6.505213034913026e-20
# Gradients for input layer weights: -4.696704033068753e-05
# Gradients for hidden layer weights: 0.0012235600884925688
# Gradients for output layer weights: -7.209944447028605e-19
# Gradients for input layer weights: 4.520558039259529e-06
# Gradients for hidden layer weights: 0.001625680327164489
# Gradients for output layer weights: 9.378348791999614e-19
# Gradients for input layer weights: -3.209076897250845e-05
# Gradients for hidden layer weights: 0.0006668058891109269
# Gradients for output layer weights: 3.957337929572091e-19
# Gradients for input layer weights: 0.000197797693629054
# Gradients for hidden layer weights: 0.0017998650126160903
# Gradients for output layer weights: -1.0516761073109392e-18
# Gradients for input layer weights: -0.00012756475660353366
# Gradients for hidden layer weights: 0.0014327999034736978
# Gradients for output layer weights: 2.1141942363467336e-19
# Gradients for input layer weights: 7.40636661300266e-06
# Gradients for hidden layer weights: 0.001251729258408571
# Gradients for output layer weights: -8.456776945386934e-19
# Gradients for input layer weights: 4.282813073758704e-05
# Gradients for hidden layer weights: 0.0010654922524984875
# Gradients for output layer weights: -2.710505431213761e-19
# Gradients for input layer weights: -4.5463848987469276e-05
# Gradients for hidden layer weights: 0.0008720623445812668
# Gradients for output layer weights: 1.0299920638612292e-18
# Gradients for input layer weights: 7.306508042452203e-05
# Gradients for hidden layer weights: 0.002018554164375558
# Gradients for output layer weights: -4.662069341687669e-19
# Gradients for input layer weights: 5.293750384350107e-06
# Gradients for hidden layer weights: 0.0009272733378840276
# Gradients for output layer weights: -6.1257422745431e-19
# Gradients for input layer weights: -0.00012234727053471098
# Gradients for hidden layer weights: 0.0007229645522397675
# Gradients for output layer weights: -7.047314121155779e-19
# Gradients for input layer weights: 2.2806356679345142e-05
# Gradients for hidden layer weights: 0.001132914068638162
# Gradients for output layer weights: -3.0899761915836877e-19
# Gradients for input layer weights: -2.1486931609231264e-05
# Gradients for hidden layer weights: 0.0007213154198265453
# Gradients for output layer weights: -1.4094628242311558e-19
# Gradients for input layer weights: 4.8838575675084454e-05
# Gradients for hidden layer weights: 0.0002473177746942325
# Gradients for output layer weights: 1.0842021724855044e-18
# Gradients for input layer weights: 4.80631221888357e-05
# Gradients for hidden layer weights: 0.0006031980129428167
# Gradients for output layer weights: 1.1167282376600696e-18
# Gradients for input layer weights: -4.027745751394784e-05
# Gradients for hidden layer weights: 0.0015952623610068376
# Gradients for output layer weights: -1.0842021724855044e-19
# Gradients for input layer weights: -3.444112804587281e-05
# Gradients for hidden layer weights: 0.0010074457572894601
# Gradients for output layer weights: 9.324138683375338e-19
# Gradients for input layer weights: -2.1160171849316086e-05
# Gradients for hidden layer weights: 0.00038099590023842804
# Gradients for output layer weights: -1.8431436932253575e-19
# Gradients for input layer weights: 4.0741838625055774e-05
# Gradients for hidden layer weights: 0.0017402576371816844
# Gradients for output layer weights: 2.710505431213761e-19
# Gradients for input layer weights: -1.3450660913727856e-05
# Gradients for hidden layer weights: 0.0004669622597945906
# Gradients for output layer weights: 1.9678269430611904e-18
# Gradients for input layer weights: 4.039110040354868e-05
# Gradients for hidden layer weights: 0.0002221437839924137
# Gradients for output layer weights: -1.0625181290357944e-18
# Gradients for input layer weights: -9.098888881130174e-05
# Gradients for hidden layer weights: 0.0015734012207767787
# Gradients for output layer weights: 1.723881454251952e-18
# Gradients for input layer weights: 7.636469797329392e-05
# Gradients for hidden layer weights: 0.0016652703379504558
# Gradients for output layer weights: 8.998878031629688e-19
# Gradients for input layer weights: -9.892890936146621e-05
# Gradients for hidden layer weights: 0.001931009675399774
# Gradients for output layer weights: -2.38524477946811e-19
# Gradients for input layer weights: 4.657833078863452e-05
# Gradients for hidden layer weights: 0.002653429202351236
# Gradients for output layer weights: 1.6263032587282567e-19
# Gradients for input layer weights: -8.157687435368515e-05
# Gradients for hidden layer weights: 0.0005381655713992087
# Gradients for output layer weights: 3.2526065174565133e-19
# Gradients for input layer weights: 3.046138754096732e-05
# Gradients for hidden layer weights: 0.0013673426865224913
# Gradients for output layer weights: 8.565197162635485e-19
# Gradients for input layer weights: 1.0335855109185768e-05
# Gradients for hidden layer weights: 0.002028812605388949
# Gradients for output layer weights: 4.98732999343332e-19
# Gradients for input layer weights: 5.938304097790641e-06
# Gradients for hidden layer weights: 0.0018984925079195776
# Gradients for output layer weights: -2.6020852139652105e-19
# Gradients for input layer weights: 2.111913817591806e-05
# Gradients for hidden layer weights: 0.0006764061141970167
# Gradients for output layer weights: 5.421010862427522e-20
# Gradients for input layer weights: -3.8379462874471926e-05
# Gradients for hidden layer weights: 0.0015196480442838977
# Gradients for output layer weights: 8.890457814381136e-19
# Gradients for input layer weights: -6.326095685160895e-05
# Gradients for hidden layer weights: 0.0016238923112443186
# Gradients for output layer weights: 8.510987054011209e-19
# Gradients for input layer weights: 4.9297974670394265e-05
# Gradients for hidden layer weights: 0.0006103051204902181
# Gradients for output layer weights: -5.854691731421724e-19
# Gradients for input layer weights: -1.6105284389449122e-06
# Gradients for hidden layer weights: 0.0013765572915086055
# Gradients for output layer weights: -1.1058862159352144e-18
# Gradients for input layer weights: -1.4764323391641263e-05
# Gradients for hidden layer weights: 0.001516685036335932
# Gradients for output layer weights: 1.734723475976807e-18
# Gradients for input layer weights: 1.7027666036261304e-05
# Gradients for hidden layer weights: 0.0017089737573184904
# Gradients for output layer weights: 4.662069341687669e-19
# Gradients for input layer weights: 1.8715731172215506e-05
# Gradients for hidden layer weights: 0.0012885595508978682
# Gradients for output layer weights: 1.0842021724855044e-18
# Gradients for input layer weights: 0.00013535181866062532
# Gradients for hidden layer weights: 0.0015918796996073601
# Gradients for output layer weights: -2.1033522146218784e-18
# Gradients for input layer weights: -6.448886972663946e-05
# Gradients for hidden layer weights: 0.0014615099457660646
# Gradients for output layer weights: -4.933119884809045e-19
# Gradients for input layer weights: 4.3720414179711525e-05
# Gradients for hidden layer weights: 0.0021588014209445987
# Gradients for output layer weights: -9.86623976961809e-19
# Gradients for input layer weights: -1.5896457451254894e-07
# Gradients for hidden layer weights: 0.001721125373915128
# Gradients for output layer weights: 1.0842021724855044e-18
# Gradients for input layer weights: -4.7153123690591956e-05
# Gradients for hidden layer weights: 0.0020732050479992568
# Gradients for output layer weights: 1.4961989980299962e-18
# Gradients for input layer weights: 0.00011339227755446367
# Gradients for hidden layer weights: 0.00220909631705826
# Gradients for output layer weights: 6.179952383167375e-19
# Gradients for input layer weights: -6.501210602718601e-05
# Gradients for hidden layer weights: 0.001208855989074322
# Gradients for output layer weights: -6.938893903907229e-19
# Gradients for input layer weights: -2.3562136117111664e-05
# Gradients for hidden layer weights: 0.0022884144774935793
# Gradients for output layer weights: -4.824699667560495e-19
# Gradients for input layer weights: 7.74487169067742e-05
# Gradients for hidden layer weights: 0.0018988983136604542
# Gradients for output layer weights: -8.456776945386934e-19
# Gradients for input layer weights: 4.707740114547049e-05
# Gradients for hidden layer weights: 0.0011139492637235958
# Gradients for output layer weights: -7.914675859144182e-19
# Gradients for input layer weights: 4.978217451863468e-05
# Gradients for hidden layer weights: 0.000526011387305659
# Gradients for output layer weights: 9.595189226496714e-19
# Gradients for input layer weights: -7.933754552287906e-05
# Gradients for hidden layer weights: 0.00032651401684276294
# Gradients for output layer weights: 6.315477654728064e-19
# Gradients for input layer weights: -2.8820395398005433e-05
# Gradients for hidden layer weights: 0.001707130941324436
# Gradients for output layer weights: -1.2197274440461925e-19
# Gradients for input layer weights: 9.735865850001789e-05
# Gradients for hidden layer weights: 0.002030484116156594
# Gradients for output layer weights: -3.361026734705064e-19
# Gradients for input layer weights: 2.420663517677984e-06
# Gradients for hidden layer weights: 0.0013852706253612188
# Gradients for output layer weights: 4.4723339615027055e-20
# Gradients for input layer weights: -0.00011085526425912677
# Gradients for hidden layer weights: 0.0025684684436695477
# Gradients for output layer weights: 6.1257422745431e-19
# Gradients for input layer weights: 4.3626071004707294e-05
# Gradients for hidden layer weights: 0.0019622274653239872
# Gradients for output layer weights: 2.168404344971009e-19
# Gradients for input layer weights: -2.7036534771448928e-06
# Gradients for hidden layer weights: 0.0017436572862433296
# Gradients for output layer weights: -1.2319247184866545e-18
# Gradients for input layer weights: 3.089515993533374e-05
# Gradients for hidden layer weights: 0.002256697325410877
# Gradients for output layer weights: -1.5178830414797062e-18
# Gradients for input layer weights: 1.4519038468315258e-05
# Gradients for hidden layer weights: 0.002053426874348135
# Gradients for output layer weights: 4.228388472693467e-19
# Gradients for input layer weights: -9.792903039411835e-05
# Gradients for hidden layer weights: 0.001905081491030363
# Gradients for output layer weights: -1.3986208025063008e-18
# Gradients for input layer weights: -5.88945364274378e-05
# Gradients for hidden layer weights: 0.0008342441834105479
# Gradients for output layer weights: -7.480994990149981e-19
# Gradients for input layer weights: 1.5554215207683272e-05
# Gradients for hidden layer weights: 0.0017815825708470377
# Gradients for output layer weights: -1.4311468676808658e-18
# Gradients for input layer weights: -2.2331677366040662e-05
# Gradients for hidden layer weights: 0.002404959620347178
# Gradients for output layer weights: 6.722053469410128e-19
# Gradients for input layer weights: -1.9023520017000405e-05
# Gradients for hidden layer weights: 0.000802435019556329
# Gradients for output layer weights: 9.75781955236954e-20
# Gradients for input layer weights: 1.7412806019841764e-05
# Gradients for hidden layer weights: 0.002499739307540242
# Gradients for output layer weights: -1.8323016715005023e-18
# Gradients for input layer weights: 1.6690182533736943e-05
# Gradients for hidden layer weights: 0.001148510153879305
# Gradients for output layer weights: 1.3118846287074603e-18
# Gradients for input layer weights: -1.7723225480779182e-05
# Gradients for hidden layer weights: 0.0015452764823404403
# Gradients for output layer weights: 6.722053469410128e-19
# Gradients for input layer weights: 1.8598498204199844e-06
# Gradients for hidden layer weights: 0.002001222103887871
# Gradients for output layer weights: -3.9302328752599536e-19
# Gradients for input layer weights: -3.185845758894776e-05
# Gradients for hidden layer weights: 0.0020276460160796117
# Gradients for output layer weights: -7.724940478959219e-19
# Gradients for input layer weights: 0.00010950855260669777
# Gradients for hidden layer weights: 0.0012290017168064128
# Gradients for output layer weights: 1.0083080204115192e-18
# Gradients for input layer weights: -0.0002175122580994276
# Gradients for hidden layer weights: 0.0011234734533781018
# Gradients for output layer weights: -7.914675859144182e-19
# Gradients for input layer weights: 4.723630357075907e-05
# Gradients for hidden layer weights: 0.0011167309734879645
# Gradients for output layer weights: -2.791820594150174e-18
# Gradients for input layer weights: -8.472471090456087e-05
# Gradients for hidden layer weights: 0.00046097638683235064
# Gradients for output layer weights: 2.168404344971009e-20
# Gradients for input layer weights: 5.738367534789456e-05
# Gradients for hidden layer weights: 0.0018213155009917138
# Gradients for output layer weights: 2.38524477946811e-19
# Gradients for input layer weights: 0.00013131579157640516
# Gradients for hidden layer weights: 0.002398243697171721
# Gradients for output layer weights: -2.0057740190981832e-18
# Gradients for input layer weights: -9.281138067870961e-05
# Gradients for hidden layer weights: 0.0014770708678211008
# Gradients for output layer weights: 8.890457814381136e-19
# Gradients for input layer weights: 2.5194548500052035e-05
# Gradients for hidden layer weights: 0.0024752970652136075
# Gradients for output layer weights: -1.0137290312739466e-18
# Gradients for input layer weights: -6.342117433673118e-05
# Gradients for hidden layer weights: 0.0012111256266212414
# Gradients for output layer weights: -8.131516293641283e-19
# Gradients for input layer weights: 0.00011390374732885956
# Gradients for hidden layer weights: 0.0009544514663133614
# Gradients for output layer weights: 1.5124620306172786e-18
# Gradients for input layer weights: -3.6944089587034586e-05
# Gradients for hidden layer weights: 0.001565783965025635
# Gradients for output layer weights: -2.2714035513571317e-18
# Gradients for input layer weights: -7.90597350181525e-05
# Gradients for hidden layer weights: 0.0009513006085181542
# Gradients for output layer weights: -1.1926223897340549e-18
# Gradients for input layer weights: -3.008636442087507e-05
# Gradients for hidden layer weights: 0.0014894561314923419
# Gradients for output layer weights: -5.854691731421724e-19
# Gradients for input layer weights: 5.56102362700456e-05
# Gradients for hidden layer weights: 0.001411463658250781
# Gradients for output layer weights: -1.485356976305141e-18
# Gradients for input layer weights: -5.901476840172894e-05
# Gradients for hidden layer weights: 0.001774470345223544
# Gradients for output layer weights: -7.37257477290143e-19
# Gradients for input layer weights: -0.00011238107105441097
# Gradients for hidden layer weights: 0.0017959312284880071
# Gradients for output layer weights: 2.0599841277224584e-18
# Gradients for input layer weights: 0.00015495688083351584
# Gradients for hidden layer weights: 0.002177210445059496
# Gradients for output layer weights: -1.1492543028346347e-18
# Gradients for input layer weights: 8.090663819974292e-05
# Gradients for hidden layer weights: 0.0015802602499207924
# Gradients for output layer weights: 3.2526065174565133e-19
# Gradients for input layer weights: -0.00016956450504291795
# Gradients for hidden layer weights: 0.0017044974680483953
# Gradients for output layer weights: -6.179952383167375e-19
# Gradients for input layer weights: -8.20724114869067e-05
# Gradients for hidden layer weights: 0.0013461249668506809
# Gradients for output layer weights: 2.981555974335137e-19
# Gradients for input layer weights: -1.1170310544788748e-06
# Gradients for hidden layer weights: 0.0013720270334436897
# Gradients for output layer weights: -9.215718466126788e-19
# Gradients for input layer weights: -6.484755657183734e-05
# Gradients for hidden layer weights: 0.00164114432752513
# Gradients for output layer weights: -9.215718466126788e-19
# Gradients for input layer weights: -2.4780735971853163e-05
# Gradients for hidden layer weights: 0.0017450930236227698
# Gradients for output layer weights: -4.98732999343332e-19
# Gradients for input layer weights: -7.89853616183352e-05
# Gradients for hidden layer weights: 0.0016087652565156972
# Gradients for output layer weights: 1.5612511283791264e-18
# Gradients for input layer weights: -0.00010904991619115778
# Gradients for hidden layer weights: 0.0004506913910896773
# Gradients for output layer weights: -4.174178364069192e-19
# Gradients for input layer weights: 5.51315430900466e-05
# Gradients for hidden layer weights: 0.0009298750952595613
# Gradients for output layer weights: -9.86623976961809e-19
# Gradients for input layer weights: -7.525210634287625e-05
# Gradients for hidden layer weights: 0.0009254659926085938
# Gradients for output layer weights: -1.2305694657710475e-18
# Gradients for input layer weights: -4.3208232170039545e-05
# Gradients for hidden layer weights: 0.001102601447168549
# Gradients for output layer weights: 2.6237692574149207e-18
# Gradients for input layer weights: 9.605684496726455e-05
# Gradients for hidden layer weights: 0.0014001408387113983
# Gradients for output layer weights: 1.0842021724855044e-19
# Gradients for input layer weights: -3.6004586237668804e-05
# Gradients for hidden layer weights: 0.0003728640447699863
# Gradients for output layer weights: 1.6263032587282567e-19
# Gradients for input layer weights: 4.646982451639466e-05
# Gradients for hidden layer weights: 0.0011528618349472084
# Gradients for output layer weights: 4.77048955893622e-19
# Gradients for input layer weights: 3.9935976371160635e-05
# Gradients for hidden layer weights: 0.0007626154303043143
# Gradients for output layer weights: -1.7889335846010822e-19
# Gradients for input layer weights: -4.497218912380118e-09
# Gradients for hidden layer weights: 0.001322624353641805
# Gradients for output layer weights: -1.0462550964485118e-18
# Gradients for input layer weights: -4.681216228369581e-05
# Gradients for hidden layer weights: 0.0016920689351408295
# Gradients for output layer weights: 1.8323016715005023e-18
# Gradients for input layer weights: 4.243755305255824e-05
# Gradients for hidden layer weights: 0.00028690343792636485
# Gradients for output layer weights: 1.3606737264693081e-18
# Gradients for input layer weights: 8.814712899861711e-05
# Gradients for hidden layer weights: 0.0008362895528051635
# Gradients for output layer weights: -5.475220971051797e-19
# Gradients for input layer weights: -3.46833694028452e-05
# Gradients for hidden layer weights: 0.0011146594455414892
# Gradients for output layer weights: 1.192622389734055e-19
# Gradients for input layer weights: -0.00010414774841571223
# Gradients for hidden layer weights: 0.001484128783732813
# Gradients for output layer weights: -1.485356976305141e-18
# Gradients for input layer weights: -3.453916785418825e-05
# Gradients for hidden layer weights: 0.0017021794655661458
# Gradients for output layer weights: -1.4311468676808658e-18
# Gradients for input layer weights: -1.9446151382778142e-05
# Gradients for hidden layer weights: 0.002463848338177795
# Gradients for output layer weights: -2.677979366039196e-18
# Gradients for input layer weights: 3.839740772159497e-05
# Gradients for hidden layer weights: 0.0010799665652584463
# Gradients for output layer weights: -8.239936510889833e-19
# Gradients for input layer weights: 6.767884254568361e-05
# Gradients for hidden layer weights: 0.0020084709314874497
# Gradients for output layer weights: -8.131516293641283e-19
# Gradients for input layer weights: 8.727474253319057e-05
# Gradients for hidden layer weights: 0.0010835745080545389
# Gradients for output layer weights: 9.107298248878238e-19
# Gradients for input layer weights: 2.7740800284425783e-05
# Gradients for hidden layer weights: 0.0015041677781911737
# Gradients for output layer weights: -3.0899761915836877e-19
# Gradients for input layer weights: 6.671526050766122e-05
# Gradients for hidden layer weights: 0.0013178803773515814
# Gradients for output layer weights: 4.228388472693467e-19
# Gradients for input layer weights: 3.9315252378828955e-05
# Gradients for hidden layer weights: 0.0025215067112205935
# Gradients for output layer weights: 1.3715157481941631e-18
# Gradients for input layer weights: -2.5047045858811485e-05
# Gradients for hidden layer weights: 0.0009542027982950383
# Gradients for output layer weights: -4.553649124439119e-19
# Gradients for input layer weights: -5.4120137043815197e-05
# Gradients for hidden layer weights: 0.0008167122587664751
# Gradients for output layer weights: -3.2526065174565133e-19
# Gradients for input layer weights: 0.00010758755581825367
# Gradients for hidden layer weights: 0.001162106528934353
# Gradients for output layer weights: 1.2034644114589099e-18
# Gradients for input layer weights: -0.0001632523093408902
# Gradients for hidden layer weights: 0.002496895327273478
# Gradients for output layer weights: -3.686287386450715e-19
# Gradients for input layer weights: 2.0369016091142522e-05
# Gradients for hidden layer weights: 0.0016367596629882283
# Gradients for output layer weights: 4.662069341687669e-19
# Gradients for input layer weights: -5.124706843096086e-05
# Gradients for hidden layer weights: 0.0017355890559976627
# Gradients for output layer weights: 1.3010426069826053e-19
# Gradients for input layer weights: -6.93041191979563e-05
# Gradients for hidden layer weights: 0.000219658257427181
# Gradients for output layer weights: 4.499439015814844e-19
# Gradients for input layer weights: -1.555242175017308e-05
# Gradients for hidden layer weights: 0.0017438914290288043
# Gradients for output layer weights: 7.58941520739853e-20
# Gradients for input layer weights: -8.13044320540556e-05
# Gradients for hidden layer weights: 0.0020440030176177362
# Gradients for output layer weights: -1.5829351718288364e-18
# Gradients for input layer weights: 7.47508353606953e-05
# Gradients for hidden layer weights: 0.0019337718564268226
# Gradients for output layer weights: 1.4094628242311558e-19
# Gradients for input layer weights: -1.967688521772255e-05
# Gradients for hidden layer weights: 0.0004995016882556624
# Gradients for output layer weights: 2.1358782797964437e-18
# Gradients for input layer weights: 5.3300581817022276e-05
# Gradients for hidden layer weights: 0.0004984603623746115
# Gradients for output layer weights: -1.8051966171883647e-18
# Gradients for input layer weights: 4.1189457198643604e-05
# Gradients for hidden layer weights: 0.0016588779503245675
# Gradients for output layer weights: -5.204170427930421e-19
# Gradients for input layer weights: 5.436573410734048e-05
# Gradients for hidden layer weights: 0.0013481522694575687
# Gradients for output layer weights: -7.58941520739853e-20
# Gradients for input layer weights: -4.174595321673721e-05
# Gradients for hidden layer weights: 0.0015863053907296944
# Gradients for output layer weights: 7.209944447028605e-19
# Gradients for input layer weights: -7.100223000961375e-05
# Gradients for hidden layer weights: 0.0021328726286596127
# Gradients for output layer weights: -1.8892222855559916e-18
# Gradients for input layer weights: -1.0531464885243527e-05
# Gradients for hidden layer weights: 0.0013892231479016295
# Gradients for output layer weights: 5.312590645178972e-19
# Gradients for input layer weights: -2.6880050498200433e-05
# Gradients for hidden layer weights: 0.00060105870443668
# Gradients for output layer weights: -1.235990476633475e-18
# Gradients for input layer weights: -3.0236964321616042e-05
# Gradients for hidden layer weights: 0.0017244872955069653
# Gradients for output layer weights: 3.035766082959412e-19
# Gradients for input layer weights: -9.040373064092447e-05
# Gradients for hidden layer weights: 0.0014619309258868706
# Gradients for output layer weights: -2.054563116860031e-18
# Gradients for input layer weights: 7.392952955666087e-05
# Gradients for hidden layer weights: 0.0018593439116361531
# Gradients for output layer weights: 1.192622389734055e-19
# Gradients for input layer weights: -1.7053432753565833e-06
# Gradients for hidden layer weights: 0.0014631889771972557
# Gradients for output layer weights: -8.348356728138384e-19
# Gradients for input layer weights: -0.0001059125884374396
# Gradients for hidden layer weights: 0.000754381209025165
# Gradients for output layer weights: -1.8431436932253575e-19
# Gradients for input layer weights: 9.7816994395418e-05
# Gradients for hidden layer weights: 0.0022932222922991447
# Gradients for output layer weights: -8.673617379884036e-20
# Gradients for input layer weights: -1.734791439568668e-06
# Gradients for hidden layer weights: 0.001440516566218603
# Gradients for output layer weights: 6.722053469410128e-19
# Gradients for input layer weights: -4.044593295037007e-05
# Gradients for hidden layer weights: 0.0016217124736231615
# Gradients for output layer weights: -1.2495430037895439e-18
# Gradients for input layer weights: 0.0001110311106370259
# Gradients for hidden layer weights: 0.0014950010296441016
# Gradients for output layer weights: -2.927345865710862e-19
# Gradients for input layer weights: 2.669882232273285e-05
# Gradients for hidden layer weights: 0.0015626118503334905
# Gradients for output layer weights: -6.1257422745431e-19
# Gradients for input layer weights: 0.00011372477766540557
# Gradients for hidden layer weights: 0.0014767579657415115
# Gradients for output layer weights: 7.480994990149981e-19
# Gradients for input layer weights: 5.7753807862275456e-05
# Gradients for hidden layer weights: 0.0008851363913194509
# Gradients for output layer weights: -1.0842021724855044e-18
# Gradients for input layer weights: 0.00014196567990193458
# Gradients for hidden layer weights: 0.0004685301171655077
# Gradients for output layer weights: -8.456776945386934e-19
# Gradients for input layer weights: 5.320784367496113e-05
# Gradients for hidden layer weights: 0.0019433388039657678
# Gradients for output layer weights: -2.981555974335137e-19
# Gradients for input layer weights: 3.993388373229869e-05
# Gradients for hidden layer weights: 0.001854662356138485
# Gradients for output layer weights: -2.3310346708438344e-19
# Gradients for input layer weights: -0.00014559865962133982
# Gradients for hidden layer weights: 0.0011643594637128435
# Gradients for output layer weights: -2.981555974335137e-19
# Gradients for input layer weights: 0.00012840883559881269
# Gradients for hidden layer weights: 0.0021189526806542733
# Gradients for output layer weights: -3.0899761915836877e-19
# Gradients for input layer weights: -8.572691501227222e-05
# Gradients for hidden layer weights: 0.0016199568666475281
# Gradients for output layer weights: -5.421010862427522e-19
# Gradients for input layer weights: -1.5168333230946671e-05
# Gradients for hidden layer weights: 0.0009235817498888094
# Gradients for output layer weights: 9.215718466126788e-19
# Gradients for input layer weights: -4.490431500180353e-05
# Gradients for hidden layer weights: 0.0015459212913284258
# Gradients for output layer weights: -1.0625181290357944e-18
# Gradients for input layer weights: -1.3253803428448566e-07
# Gradients for hidden layer weights: 0.002052975311587949
# Gradients for output layer weights: 1.0191500421363742e-18
# Gradients for input layer weights: 2.9557723424989904e-05
# Gradients for hidden layer weights: 0.0013607852632731019
# Gradients for output layer weights: -1.3010426069826053e-19
# Gradients for input layer weights: 4.997514293542529e-05
# Gradients for hidden layer weights: 0.001663687423551662
# Gradients for output layer weights: -1.8865117801247776e-18
# Gradients for input layer weights: -0.00013871444058441442
# Gradients for hidden layer weights: 0.0009177542850192842
# Gradients for output layer weights: 1.3010426069826053e-19
# Gradients for input layer weights: -1.915438422810952e-05
# Gradients for hidden layer weights: 0.00281316826007005
# Gradients for output layer weights: 6.938893903907229e-19
# Gradients for input layer weights: -1.6962923483590408e-05
# Gradients for hidden layer weights: 0.0017974827230329182
# Gradients for output layer weights: 1.7021974108022419e-18
# Gradients for input layer weights: 2.4708009917008127e-05
# Gradients for hidden layer weights: 0.0016373302667756049
# Gradients for output layer weights: -1.4094628242311558e-18
# Gradients for input layer weights: -7.476140503556504e-05
# Gradients for hidden layer weights: 0.0012608677079509506
# Gradients for output layer weights: 1.599198204416119e-18
# Gradients for input layer weights: 0.0001300180769272373
# Gradients for hidden layer weights: 0.001110921212071821
# Gradients for output layer weights: 2.38524477946811e-19
# Gradients for input layer weights: -8.418099394337648e-05
# Gradients for hidden layer weights: 0.0022245190622581326
# Gradients for output layer weights: 1.474514954580286e-18
# Gradients for input layer weights: -4.5960057876839694e-05
# Gradients for hidden layer weights: 0.0014092482917736713
# Gradients for output layer weights: 1.6696713456276769e-18
# Gradients for input layer weights: -6.051746017938058e-06
# Gradients for hidden layer weights: 0.0005328115313543531
# Gradients for output layer weights: 6.179952383167375e-19
# Gradients for input layer weights: -7.833581901964162e-05
# Gradients for hidden layer weights: 0.0014743789440457042
# Gradients for output layer weights: 2.179246366695864e-18
# Gradients for input layer weights: -9.916886161648234e-05
# Gradients for hidden layer weights: 0.0019855858840469275
# Gradients for output layer weights: 1.2305694657710475e-18
# Gradients for input layer weights: 3.6326166023216785e-05
# Gradients for hidden layer weights: 0.0014432112308255642
# Gradients for output layer weights: 3.3393426912553537e-18
# Gradients for input layer weights: 7.914872593080038e-06
# Gradients for hidden layer weights: 0.0015002123959449412
# Gradients for output layer weights: -9.215718466126788e-19
# Gradients for input layer weights: -3.0210412254457423e-05
# Gradients for hidden layer weights: 0.002045800052834793
# Gradients for output layer weights: 6.071532165918824e-19
# Gradients for input layer weights: 8.809655105740388e-05
# Gradients for hidden layer weights: 0.001952285713315563
# Gradients for output layer weights: 4.0115480381963666e-19
# Gradients for input layer weights: -2.5876869660565256e-05
# Gradients for hidden layer weights: 0.0016392164773039724
# Gradients for output layer weights: -2.1141942363467336e-18
# Gradients for input layer weights: -8.958610580037801e-05
# Gradients for hidden layer weights: 0.0018968574397678504
# Gradients for output layer weights: -3.035766082959412e-19
# Gradients for input layer weights: 2.820828627557591e-06
# Gradients for hidden layer weights: 0.001139868391959173
# Gradients for output layer weights: -1.111307226797642e-18
# Gradients for input layer weights: -0.00015825352824288145
# Gradients for hidden layer weights: 0.0015459925032845977
# Gradients for output layer weights: -8.998878031629688e-19
# Gradients for input layer weights: 3.13900453019695e-05
# Gradients for hidden layer weights: 0.0015589595585499857
# Gradients for output layer weights: -1.0299920638612292e-18
# Gradients for input layer weights: -2.4037110238192486e-05
# Gradients for hidden layer weights: 0.00139307863676334
# Gradients for output layer weights: -3.225501463144376e-19
# Gradients for input layer weights: 2.713000657751672e-06
# Gradients for hidden layer weights: 0.0013458102555613267
# Gradients for output layer weights: 2.211772431870429e-18
# ...
# Gradients for hidden layer weights: 0.0007449987051299058
# Gradients for output layer weights: -7.26415455565288e-19
# Gradients for input layer weights: -0.00011266318549390916
# Gradients for hidden layer weights: 0.00075110794788474
# Gradients for output layer weights: -8.998878031629688e-19
# Gradients for input layer weights: -3.914878094414524e-05
# Gradients for hidden layer weights: 0.002059823086700595
# Gradients for output layer weights: 6.505213034913027e-19
# Gradients for input layer weights: 7.823394584080449e-05
# Gradients for hidden layer weights: 0.0010966386274508973
# Gradients for output layer weights: -1.0842021724855045e-20
# Gradients for input layer weights: 3.5132499646213186e-05
# Gradients for hidden layer weights: 0.00028631820671960197
# Gradients for output layer weights: -8.863352760069e-19
# Gradients for input layer weights: -8.938692591537948e-05
# Gradients for hidden layer weights: 0.0013205772678440346
# Gradients for output layer weights: -9.75781955236954e-19
# Gradients for input layer weights: -0.00011263501844607111
# Gradients for hidden layer weights: 0.0018331006094893412
# Gradients for output layer weights: -1.0950441942103594e-18
# Gradients for input layer weights: 8.115855525151021e-05
# Gradients for hidden layer weights: 0.0005719117368908754
# Gradients for output layer weights: -1.0733601507606494e-18
# Gradients for input layer weights: -1.1952564386626377e-05
# Gradients for hidden layer weights: 0.0012861922890386377
# Gradients for output layer weights: -1.3118846287074603e-18
# Gradients for input layer weights: -3.980191553829262e-05
# Gradients for hidden layer weights: 0.0010409468316389561
# Gradients for output layer weights: -1.2902005852577503e-18
# Gradients for input layer weights: -3.9113330741393945e-05
# Gradients for hidden layer weights: 0.0020409922566753036
# Gradients for output layer weights: -7.047314121155779e-20
# Gradients for input layer weights: -2.4444568234101626e-05
# Gradients for hidden layer weights: 0.0017386750011408243
# Gradients for output layer weights: 1.0625181290357944e-18
# Gradients for input layer weights: -7.062359009252128e-05
# Gradients for hidden layer weights: 0.0010840809569725865
# Gradients for output layer weights: 6.288372600415926e-19
# Gradients for input layer weights: -3.450151228045305e-05
# Gradients for hidden layer weights: 0.0010391128721011472
# Gradients for output layer weights: -1.0625181290357944e-18
# Gradients for input layer weights: 3.69118056444008e-05
# Gradients for hidden layer weights: 0.0012922847345867156
# Gradients for output layer weights: 3.252606517456513e-20
# Gradients for input layer weights: -4.5108558665953474e-05
# Gradients for hidden layer weights: 0.001087147853881388
# Gradients for output layer weights: 4.336808689942018e-20
# Gradients for input layer weights: -3.5716281031119527e-05
# Gradients for hidden layer weights: 0.0016232909193161934
# Gradients for output layer weights: -3.415236843329339e-19
# Gradients for input layer weights: 1.668265126602312e-05
# Gradients for hidden layer weights: 0.002063003160579905
# Gradients for output layer weights: 6.505213034913027e-19
# Gradients for input layer weights: 4.3774148985969223e-05
# Gradients for hidden layer weights: 0.0015050201057405462
# Gradients for output layer weights: 1.192622389734055e-19
# Gradients for input layer weights: -5.680028332353485e-06
# Gradients for hidden layer weights: 0.0022735912863937066
# Gradients for output layer weights: -4.933119884809045e-19
# Gradients for input layer weights: -0.00014940113447091592
# Gradients for hidden layer weights: 0.0011649049525921389
# Gradients for output layer weights: 2.168404344971009e-20
# Gradients for input layer weights: -2.2788439264149403e-05
# Gradients for hidden layer weights: 0.0017035612670091246
# Gradients for output layer weights: 1.7997756063259375e-18
# Gradients for input layer weights: -0.0002186258028459878
# Gradients for hidden layer weights: 0.0006806957785589356
# Gradients for output layer weights: 3.144186300207963e-19
# Gradients for input layer weights: -4.287304704468592e-05
# Gradients for hidden layer weights: 0.0017099227759652558
# Gradients for output layer weights: 8.673617379884036e-20
# Gradients for input layer weights: -4.964276214373946e-05
# Gradients for hidden layer weights: 0.0020284087375395886
# Gradients for output layer weights: 1.2847795743953227e-18
# Gradients for input layer weights: -6.365455164011699e-05
# Gradients for hidden layer weights: 0.0022044886699333333
# Gradients for output layer weights: -1.1817803680091999e-18
# Gradients for input layer weights: 6.797786346915771e-05
# Gradients for hidden layer weights: 0.0017018231212682705
# Gradients for output layer weights: -2.49366499671666e-19
# Gradients for input layer weights: -6.660255417692257e-05
# Gradients for hidden layer weights: 0.0021829923424165187
# Gradients for output layer weights: 1.2468324983583301e-18
# Gradients for input layer weights: -5.8255956089516345e-05
# Gradients for hidden layer weights: 0.001789624879038168
# Gradients for output layer weights: -6.179952383167375e-19
# Gradients for input layer weights: -4.1484400269979974e-05
# Gradients for hidden layer weights: 0.0026135967910909897
# Gradients for output layer weights: -2.2768245622195593e-18
# Gradients for input layer weights: 3.7620642978844845e-05
# Gradients for hidden layer weights: 0.0027011196653606846
# Gradients for output layer weights: -1.951563910473908e-19
# Gradients for input layer weights: -0.00016274323462100285
# Gradients for hidden layer weights: 0.0002585465791770712
# Gradients for output layer weights: -1.2739375526704677e-18
# Gradients for input layer weights: -3.200886354303838e-05
# Gradients for hidden layer weights: 0.0019342154759373433
# Gradients for output layer weights: -6.2341624917916505e-19
# Gradients for input layer weights: -1.3486332785134342e-05
# Gradients for hidden layer weights: 0.0005780292147817055
# Gradients for output layer weights: 2.2334564753201393e-18
# Gradients for input layer weights: -5.5066314911855555e-05
# Gradients for hidden layer weights: 0.0009038915812602197
# Gradients for output layer weights: 2.5614276324970042e-18
# Gradients for input layer weights: -2.5077831214401197e-05
# Gradients for hidden layer weights: 0.0013447687843331241
# Gradients for output layer weights: -2.0057740190981833e-19
# Gradients for input layer weights: 8.048717057278355e-05
# Gradients for hidden layer weights: 0.002151234671449675
# Gradients for output layer weights: 7.480994990149981e-19
# Gradients for input layer weights: 9.637453039697736e-06
# Gradients for hidden layer weights: 0.001649174957624608
# Gradients for output layer weights: 1.5341460740669888e-18
# Gradients for input layer weights: 4.2645630094050275e-05
# Gradients for hidden layer weights: 0.002404160526038086
# Gradients for output layer weights: -2.5695591487906454e-18
# Gradients for input layer weights: -7.08079612608567e-05
# Gradients for hidden layer weights: 0.000699807747275601
# Gradients for output layer weights: -3.7947076036992655e-19
# Gradients for input layer weights: -3.49522900985787e-05
# Gradients for hidden layer weights: 0.0012025687271015359
# Gradients for output layer weights: -1.1709383462843449e-18
# Gradients for input layer weights: 0.00011460464813141685
# Gradients for hidden layer weights: 0.0015305532676712459
# Gradients for output layer weights: 5.204170427930421e-19
# Gradients for input layer weights: -8.520613175056396e-06
# Gradients for hidden layer weights: 0.0011415318063343093
# Gradients for output layer weights: 2.4286128663675298e-18
# Gradients for input layer weights: 0.00010584087683964144
# Gradients for hidden layer weights: 0.0014855903478761515
# Gradients for output layer weights: -1.0272815584300154e-18
# Gradients for input layer weights: 5.006202941801976e-05
# Gradients for hidden layer weights: 0.001672048350278252
# Gradients for output layer weights: -1.6805133673525319e-18
# Gradients for input layer weights: 2.4520663578127674e-05
# Gradients for hidden layer weights: 0.0014985185164361908
# Gradients for output layer weights: -8.565197162635485e-19
# Gradients for input layer weights: 2.9778891667450893e-05
# Gradients for hidden layer weights: 0.0019035655181393833
# Gradients for output layer weights: 1.7536970139953035e-18
# Gradients for input layer weights: -0.00014842770980319343
# Gradients for hidden layer weights: 0.0013665032665694681
# Gradients for output layer weights: 1.1492543028346347e-18
# Gradients for input layer weights: -6.424579430016681e-05
# Gradients for hidden layer weights: 0.00040775127960522475
# Gradients for output layer weights: -2.8731357570865867e-19
# Gradients for input layer weights: 3.309048837375521e-05
# Gradients for hidden layer weights: 0.002019629845579478
# Gradients for output layer weights: -2.8731357570865867e-19
# Gradients for input layer weights: -7.988659270581544e-05
# Gradients for hidden layer weights: 0.0010304486820172528
# Gradients for output layer weights: 1.3986208025063008e-18
# Gradients for input layer weights: 3.538381794761607e-05
# Gradients for hidden layer weights: 0.002347258298568692
# Gradients for output layer weights: 1.3769367590565906e-18
# Gradients for input layer weights: -0.0001462074790363271
# Gradients for hidden layer weights: 0.001262806423120459
# Gradients for output layer weights: 1.6168164897190084e-18
# Gradients for input layer weights: -7.036608335600055e-05
# Gradients for hidden layer weights: 0.0008794344090414393
# Gradients for output layer weights: 4.87890977618477e-20
# Gradients for input layer weights: 3.4423245725680884e-05
# Gradients for hidden layer weights: 0.001334060986078204
# Gradients for output layer weights: -1.474514954580286e-18
# Gradients for input layer weights: 0.00011398744020608772
# Gradients for hidden layer weights: 0.0010568446236038566
# Gradients for output layer weights: 2.927345865710862e-19
# Gradients for input layer weights: -4.820085568675818e-05
# Gradients for hidden layer weights: 0.0003537317797018649
# Gradients for output layer weights: -7.58941520739853e-20
# Gradients for input layer weights: -4.790899251140186e-05
# Gradients for hidden layer weights: 0.0014256761129800596
# Gradients for output layer weights: 1.2143064331837649e-18
# Gradients for input layer weights: 8.852972749337559e-05
# Gradients for hidden layer weights: 0.0011694049694348264
# Gradients for output layer weights: 1.7889335846010823e-18
# Gradients for input layer weights: -6.304420749476063e-05
# Gradients for hidden layer weights: 0.0004009612831012042
# Gradients for output layer weights: -1.2576745200831851e-18
# Gradients for input layer weights: -3.614278839337992e-05
# Gradients for hidden layer weights: 0.0012222805005101059
# Gradients for output layer weights: 6.2612675461037885e-19
# Gradients for input layer weights: -4.1938366816211877e-05
# Gradients for hidden layer weights: 0.0007837797312767731
# Gradients for output layer weights: 1.2739375526704678e-19
# Gradients for input layer weights: -0.0001519307674658026
# Gradients for hidden layer weights: 0.001815723970252382
# Gradients for output layer weights: -1.3552527156068805e-18
# Gradients for input layer weights: -0.00010728197854765211
# Gradients for hidden layer weights: 0.0019269166394032798
# Gradients for output layer weights: -6.505213034913027e-19
# Gradients for input layer weights: 8.654295906386755e-05
# Gradients for hidden layer weights: 0.000785213832286441
# Gradients for output layer weights: 6.613633252161577e-19
# Gradients for input layer weights: -9.500562836145123e-05
# Gradients for hidden layer weights: 0.0011134906014804353
# Gradients for output layer weights: -1.021860547567588e-18
# Gradients for input layer weights: 2.212994153737194e-05
# Gradients for hidden layer weights: 0.001307763599100154
# Gradients for output layer weights: 3.361026734705064e-19
# Gradients for input layer weights: 1.2132417090945852e-05
# Gradients for hidden layer weights: 0.0004991374244008897
# Gradients for output layer weights: -1.2468324983583301e-18
# Gradients for input layer weights: 6.269148131237257e-05
# Gradients for hidden layer weights: 0.002033916023394461
# Gradients for output layer weights: -2.076247160309741e-18
# Gradients for input layer weights: 0.0001238051461347439
# Gradients for hidden layer weights: 0.0009604826440514081
# Gradients for output layer weights: 7.047314121155779e-19
# Gradients for input layer weights: 9.435324203224236e-05
# Gradients for hidden layer weights: 0.0007997843045219591
# Gradients for output layer weights: 9.97465998686664e-19
# Gradients for input layer weights: 1.601039232257873e-05
# Gradients for hidden layer weights: 0.002058958094423137
# Gradients for output layer weights: 1.2847795743953227e-18
# Gradients for input layer weights: -1.317653437154145e-06
# Gradients for hidden layer weights: 0.0022028294351855004
# Gradients for output layer weights: -3.0140820395097024e-18
# Gradients for input layer weights: 7.701409387845197e-05
# Gradients for hidden layer weights: 0.00041650815339059027
# Gradients for output layer weights: 1.0299920638612292e-19
# Gradients for input layer weights: -0.00011107043321164442
# Gradients for hidden layer weights: 0.0018956155562747557
# Gradients for output layer weights: -1.5720931501039814e-18
# Gradients for input layer weights: -9.468461507928285e-05
# Gradients for hidden layer weights: 0.0018761468244990745
# Gradients for output layer weights: -1.0191500421363742e-18
# Gradients for input layer weights: 4.327822933988995e-05
# Gradients for hidden layer weights: 0.0016711120074530163
# Gradients for output layer weights: -1.485356976305141e-18
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 28
#      26 for epoch in range(num_epochs):
#      27     epoch_loss = 0
# ---> 28     for batch_idx, (data, target) in enumerate(train_loader):
#      29         # Prepare input and labels
#      30         data = data.view(-1, 28*28).numpy()
#      31         data = (data - data.mean()) / (data.std() + 1e-8)
#
# File ~/Course/Computer Vision/Project1/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:701, in _BaseDataLoaderIter.__next__(self)
#     698 if self._sampler_iter is None:
#     699     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     700     self._reset()  # type: ignore[call-arg]
# --> 701 data = self._next_data()
#     702 self._num_yielded += 1
#     703 if (
#     704     self._dataset_kind == _DatasetKind.Iterable
#     705     and self._IterableDataset_len_called is not None
#     706     and self._num_yielded > self._IterableDataset_len_called
#     707 ):
#
# File ~/Course/Computer Vision/Project1/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:757, in _SingleProcessDataLoaderIter._next_data(self)
#     755 def _next_data(self):
#     756     index = self._next_index()  # may raise StopIteration
# --> 757     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     758     if self._pin_memory:
#     759         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/Course/Computer Vision/Project1/.venv/lib/python3.12/site-packages/torch/utils/data/_utils/fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# File ~/Course/Computer Vision/Project1/.venv/lib/python3.12/site-packages/torchvision/datasets/mnist.py:139, in MNIST.__getitem__(self, index)
#     131 def __getitem__(self, index: int) -> Tuple[Any, Any]:
#     132     """
#     133     Args:
#     134         index (int): Index
#    (...)
#     137         tuple: (image, target) where target is index of the target class.
#     138     """
# --> 139     img, target = self.data[index], int(self.targets[index])
#     141     # doing this so that it is consistent with all other datasets
#     142     # to return a PIL Image
#     143     img = Image.fromarray(img.numpy(), mode="L")
#
# KeyboardInterrupt:

# %%
from src.activation import Softmax
softmax = Softmax()
correct = 0
total = 0
for data, target in test_loader:
    data = data.view(-1, 28*28).numpy()
    target = target.numpy()
    
    # Forward pass
    out = input_layer.forward(data)
    out = relu1.forward(out)
    out = hidden_layer.forward(out)
    out = relu2.forward(out)
    out = output_layer.forward(out)
    logits = softmax.forward(out)
    
    predicted = np.argmax(logits, axis=1)
    total += target.size
    correct += (predicted == target).sum()
accuracy = 100 * correct / total
print(f'Test Accuracy: {accuracy:.2f}%')
# Out:
# Test Accuracy: 9.13%
